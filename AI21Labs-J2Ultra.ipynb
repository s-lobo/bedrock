# %%
import boto3, json

bedrock_runtime = boto3.client(
    service_name='bedrock-runtime',
    region_name='us-east-1'
)

prompt = "Is the proto molecule real?"

kwargs = {
  "modelId": "ai21.j2-ultra-v1",
  "contentType": "application/json",
  "accept": "*/*",
  "body": "{\"prompt\":\"" + prompt + "\",\"maxTokens\":200,\"temperature\":0.7,\"topP\":1,\"stopSequences\":[],\"countPenalty\":{\"scale\":0},\"presencePenalty\":{\"scale\":0},\"frequencyPenalty\":{\"scale\":0}}"
}

response = bedrock_runtime.invoke_model(**kwargs)
response
# Out:
# {'ResponseMetadata': {'RequestId': '4b1e02cc-6dcf-4ad9-b23b-5665eaefa629',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Thu, 19 Oct 2023 22:38:35 GMT',
#    'content-type': 'application/json',
#    'content-length': '5299',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '4b1e02cc-6dcf-4ad9-b23b-5665eaefa629'},
#   'RetryAttempts': 0},
#  'contentType': 'application/json',
#  'body': <botocore.response.StreamingBody at 0x105dc65f0>}

# %%
response_body = json.loads(response.get('body').read())
response_body
# Out:
# {'id': 1234,
#  'prompt': {'text': 'Is the proto molecule real?',
#   'tokens': [{'generatedToken': {'token': '▁Is▁the',
#      'logprob': -9.698254585266113,
#      'raw_logprob': -9.698254585266113},
#     'topTokens': None,
#     'textRange': {'start': 0, 'end': 6}},
#    {'generatedToken': {'token': '▁proto',
#      'logprob': -13.42811107635498,
#      'raw_logprob': -13.42811107635498},
#     'topTokens': None,
#     'textRange': {'start': 6, 'end': 12}},
#    {'generatedToken': {'token': '▁molecule',
#      'logprob': -10.568026542663574,
#      'raw_logprob': -10.568026542663574},
#     'topTokens': None,
#     'textRange': {'start': 12, 'end': 21}},
#    {'generatedToken': {'token': '▁real',
#      'logprob': -1.7002782821655273,
#      'raw_logprob': -1.7002782821655273},
#     'topTokens': None,
#     'textRange': {'start': 21, 'end': 26}},
#    {'generatedToken': {'token': '?',
#      'logprob': -11.281292915344238,
#      'raw_logprob': -11.281292915344238},
#     'topTokens': None,
#     'textRange': {'start': 26, 'end': 27}}]},
#  'completions': [{'data': {'text': '\nThe Protomolecule is a fictional object from the science fiction television show The Expanse, which airs on Syfy and Amazon Prime Video. It is not real.',
#     'tokens': [{'generatedToken': {'token': '<|newline|>',
#        'logprob': 0.0,
#        'raw_logprob': -1.6331539882230572e-05},
#       'topTokens': None,
#       'textRange': {'start': 0, 'end': 1}},
#      {'generatedToken': {'token': '▁The',
#        'logprob': -0.4749763607978821,
#        'raw_logprob': -0.8505406379699707},
#       'topTokens': None,
#       'textRange': {'start': 1, 'end': 4}},
#      {'generatedToken': {'token': '▁Proto',
#        'logprob': -0.15828515589237213,
#        'raw_logprob': -0.25613173842430115},
#       'topTokens': None,
#       'textRange': {'start': 4, 'end': 10}},
#      {'generatedToken': {'token': 'molecule',
#        'logprob': -0.022786449640989304,
#        'raw_logprob': -0.07303769886493683},
#       'topTokens': None,
#       'textRange': {'start': 10, 'end': 18}},
#      {'generatedToken': {'token': '▁is',
#        'logprob': -0.12555192410945892,
#        'raw_logprob': -0.2375839352607727},
#       'topTokens': None,
#       'textRange': {'start': 18, 'end': 21}},
#      {'generatedToken': {'token': '▁a▁fictional',
#        'logprob': -1.8000440832111053e-05,
#        'raw_logprob': -0.0005208089714869857},
#       'topTokens': None,
#       'textRange': {'start': 21, 'end': 33}},
#      {'generatedToken': {'token': '▁object',
#        'logprob': -0.35675355792045593,
#        'raw_logprob': -0.7376567125320435},
#       'topTokens': None,
#       'textRange': {'start': 33, 'end': 40}},
#      {'generatedToken': {'token': '▁from▁the',
#        'logprob': -0.1779281347990036,
#        'raw_logprob': -0.4475299119949341},
#       'topTokens': None,
#       'textRange': {'start': 40, 'end': 49}},
#      {'generatedToken': {'token': '▁science▁fiction',
#        'logprob': -0.181692972779274,
#        'raw_logprob': -0.43571096658706665},
#       'topTokens': None,
#       'textRange': {'start': 49, 'end': 65}},
#      {'generatedToken': {'token': '▁television▁show',
#        'logprob': -2.109816551208496,
#        'raw_logprob': -1.7100170850753784},
#       'topTokens': None,
#       'textRange': {'start': 65, 'end': 81}},
#      {'generatedToken': {'token': '▁The',
#        'logprob': -5.384288311004639,
#        'raw_logprob': -3.79213547706604},
#       'topTokens': None,
#       'textRange': {'start': 81, 'end': 85}},
#      {'generatedToken': {'token': '▁Exp',
#        'logprob': -1.4305104514278355e-06,
#        'raw_logprob': -0.00011598391574807465},
#       'topTokens': None,
#       'textRange': {'start': 85, 'end': 89}},
#      {'generatedToken': {'token': 'an',
#        'logprob': -0.16833829879760742,
#        'raw_logprob': -0.2661904990673065},
#       'topTokens': None,
#       'textRange': {'start': 89, 'end': 91}},
#      {'generatedToken': {'token': 'se',
#        'logprob': 0.0,
#        'raw_logprob': -4.768370445162873e-07},
#       'topTokens': None,
#       'textRange': {'start': 91, 'end': 93}},
#      {'generatedToken': {'token': ',',
#        'logprob': -6.687417771900073e-05,
#        'raw_logprob': -0.002402516780421138},
#       'topTokens': None,
#       'textRange': {'start': 93, 'end': 94}},
#      {'generatedToken': {'token': '▁which',
#        'logprob': -0.5354259014129639,
#        'raw_logprob': -0.8542343974113464},
#       'topTokens': None,
#       'textRange': {'start': 94, 'end': 100}},
#      {'generatedToken': {'token': '▁airs',
#        'logprob': -0.4298095405101776,
#        'raw_logprob': -0.6236658096313477},
#       'topTokens': None,
#       'textRange': {'start': 100, 'end': 105}},
#      {'generatedToken': {'token': '▁on',
#        'logprob': -0.13685573637485504,
#        'raw_logprob': -0.2319517880678177},
#       'topTokens': None,
#       'textRange': {'start': 105, 'end': 108}},
#      {'generatedToken': {'token': '▁Syfy',
#        'logprob': -0.16470830142498016,
#        'raw_logprob': -0.31583690643310547},
#       'topTokens': None,
#       'textRange': {'start': 108, 'end': 113}},
#      {'generatedToken': {'token': '▁and',
#        'logprob': -0.16153205931186676,
#        'raw_logprob': -0.2827724516391754},
#       'topTokens': None,
#       'textRange': {'start': 113, 'end': 117}},
#      {'generatedToken': {'token': '▁Amazon▁Prime',
#        'logprob': -0.03722766786813736,
#        'raw_logprob': -0.13743026554584503},
#       'topTokens': None,
#       'textRange': {'start': 117, 'end': 130}},
#      {'generatedToken': {'token': '▁Video',
#        'logprob': -0.02038971707224846,
#        'raw_logprob': -0.0645265057682991},
#       'topTokens': None,
#       'textRange': {'start': 130, 'end': 136}},
#      {'generatedToken': {'token': '.',
#        'logprob': -4.887569048150908e-06,
#        'raw_logprob': -0.0003000047872774303},
#       'topTokens': None,
#       'textRange': {'start': 136, 'end': 137}},
#      {'generatedToken': {'token': '▁It▁is▁not',
#        'logprob': -0.034162141382694244,
#        'raw_logprob': -0.12720279395580292},
#       'topTokens': None,
#       'textRange': {'start': 137, 'end': 147}},
#      {'generatedToken': {'token': '▁real',
#        'logprob': -0.47262346744537354,
#        'raw_logprob': -0.590324342250824},
#       'topTokens': None,
#       'textRange': {'start': 147, 'end': 152}},
#      {'generatedToken': {'token': '.',
#        'logprob': -0.5269023180007935,
#        'raw_logprob': -0.7142226696014404},
#       'topTokens': None,
#       'textRange': {'start': 152, 'end': 153}},
#      {'generatedToken': {'token': '<|endoftext|>',
#        'logprob': -0.32380345463752747,
#        'raw_logprob': -0.5965937972068787},
#       'topTokens': None,
#       'textRange': {'start': 153, 'end': 153}}]},
#    'finishReason': {'reason': 'endoftext'}}]}

# %%
completion = response_body.get('completions')[0].get('data').get('text')
completion
# Out:
# '\nThe Protomolecule is a fictional object from the science fiction television show The Expanse, which airs on Syfy and Amazon Prime Video. It is not real.'
